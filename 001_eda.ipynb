# %%
# --- 1. CONFIGURAÇÃO DO AMBIENTE ---

# Importação de bibliotecas padrão
import pandas as pd
import numpy as np
import os
import sys
from statsmodels.tsa.api import SARIMAX
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter


# Configurações de visualização para os gráficos
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (18, 7)
plt.rcParams['font.size'] = 12

# %%
df1 = pd.read_csv(r"/Users/universo369/Documents/RESIDENCIA EM TI - TJGO + TJGO/TJGO/predict_series_criminal_tjgo/data/raw_data/df_go_seg_pub_2015-2025.csv")
# Out:
# /var/folders/4j/d4kpj1rj1b1dpkqqdvjc98ph0000gn/T/ipykernel_12112/1667141991.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r"/Users/universo369/Documents/RESIDENCIA EM TI - TJGO + TJGO/TJGO/predict_series_criminal_tjgo/data/raw_data/df_go_seg_pub_2015-2025.csv")

# %%
df1.head(15)
# Out:
#     uf      municipio                evento      data_referencia agente arma  \
# 0   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-01-01 00:00:00    NaN  NaN
# 1   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-02-01 00:00:00    NaN  NaN
# 2   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-03-01 00:00:00    NaN  NaN
# 3   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-04-01 00:00:00    NaN  NaN
# 4   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-05-01 00:00:00    NaN  NaN
# 5   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-06-01 00:00:00    NaN  NaN
# 6   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-07-01 00:00:00    NaN  NaN
# 7   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-08-01 00:00:00    NaN  NaN
# 8   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-09-01 00:00:00    NaN  NaN
# 9   GO  NÃO INFORMADO  Apreensão de Cocaína  2015-10-01 00:00:00    NaN  NaN
# 10  GO  NÃO INFORMADO  Apreensão de Cocaína  2015-11-01 00:00:00    NaN  NaN
# ...
